# %% [markdown]
# **운전자 이상행동 데이터셋 다운로드 및 변환**

# %%
import os
import shutil
import json
import random
from tqdm import tqdm
from google.colab import files
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/CAB/CAB_dataset/JPEGImages
# !unzip -qq "/content/drive/MyDrive/CAB/CAB_dataset/JPEGImages/images_bbox.zip"
# Out:
# /content/drive/MyDrive/CAB/CAB_dataset/JPEGImages

# %%
# %cd /content/drive/MyDrive/CAB/CAB_dataset/Annotations
# !unzip -qq "/content/drive/MyDrive/CAB/CAB_dataset/Annotations/label_bbox.zip"
# Out:
# /content/drive/MyDrive/CAB/CAB_dataset/temp
# unzip:  cannot find or open /content/drive/MyDrive/CAB/CAB_dataset/temp/졸음운전 예방을 위한 운전자 상태 정보 영상, /content/drive/MyDrive/CAB/CAB_dataset/temp/졸음운전 예방을 위한 운전자 상태 정보 영상.zip or /content/drive/MyDrive/CAB/CAB_dataset/temp/졸음운전 예방을 위한 운전자 상태 정보 영상.ZIP.

# %% [markdown]
# 파일 경로 변환
# - /content/drive/MyDrive/CAB/CAB_dataset/JPEGImages 하위 디렉토리에 있는 이미지를 /content/drive/MyDrive/CAB/CAB_dataset/JPEGImages로 옮김
# - /content/drive/MyDrive/CAB/CAB_dataset/Annotations 하위 디렉토리에 있는 이미지를 /content/drive/MyDrive/CAB/CAB_dataset/Annotations로 옮김

# %%
def move_file(base_dir):
  for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.lower().endswith(('.jpg', 'json')):
            source_path = os.path.join(root, file)
            destination_path = os.path.join(base_dir, file)

            shutil.move(source_path, destination_path)

jpeg_dir = "/content/drive/MyDrive/CAB/CAB_dataset/JPEGImages"
annot_dir = "/content/drive/MyDrive/CAB/CAB_dataset/Annotations"

move_file(jpeg_dir)
move_file(annot_dir)

# %% [markdown]
# json 파일 형태를 YOLOv5 훈련에 사용할 수 있도록 txt로 변환한다.

# %%
class_mapping = {
      "Face": 0,
      "Leye": 1,
      "Reye": 2,
      "Mouth": 3,
      "Cigar": 4,
      "Phone": 5
}

# %%
source_path = "/content/drive/MyDrive/CAB/CAB_dataset/Annotations/"
dest_path = "/content/drive/MyDrive/CAB/CAB_dataset/TextAnnotations/"

# 지정된 경로에 있는 모든 파일과 디렉토리를 가져옴
json_files = [f for f in os.listdir(source_path) if f.endswith('.json')]

for json_file in json_files:
  file_path = os.path.join(source_path, json_file)

  with open(file_path, 'r', encoding='utf-8') as f:
      data = json.load(f)

  file_name = data["FileInfo"]["FileName"].split(".")[0]

  # 이미지 크기
  img_width = data["FileInfo"]["Width"]
  img_height = data["FileInfo"]["Height"]

  # txt 파일을 생성할 리스트
  yolo_data = []

  # 바운딩 박스를 확인하여 YOLO 형식으로 변환
  for obj, bbox in data["ObjectInfo"]["BoundingBox"].items():
      if bbox["isVisible"]:
          class_id = class_mapping[obj]
          xmin, ymin, xmax, ymax = bbox["Position"]

          # YOLO 형식의 바운딩 박스 (중앙 좌표와 크기) 계산
          x_center = (xmin + xmax) / 2 / img_width
          y_center = (ymin + ymax) / 2 / img_height
          width = (xmax - xmin) / img_width
          height = (ymax - ymin) / img_height

          # YOLO 포맷: 클래스 ID와 정규화된 좌표
          yolo_data.append(f"{class_id} {x_center} {y_center} {width} {height}")

  output_file = os.path.join(dest_path, file_name + ".txt")

  with open(output_file, "w") as f:
      for line in yolo_data:
          f.write(line + "\n")

# %% [markdown]
# 다음으로, 모든 Image의 절대 경로가 적힌 리스트를 만든다.

# %%
base_path = "/content/drive/MyDrive/CAB/CAB_dataset/JPEGImages"
img_files = []

for file in os.listdir(base_path):
  if file.endswith(".jpg"):
    file_path = os.path.join(base_path, file)
    img_files.append(file_path)

# %% [markdown]
# yolo 학습을 위해 annotation 파일과 image 파일을 한 폴더로 옮긴다.

# %%
img_source_path = "/content/drive/MyDrive/CAB/CAB_dataset/JPEGImages/"
txt_source_path = "/content/drive/MyDrive/CAB/CAB_dataset/TextAnnotations/"
dest_path = "/content/drive/MyDrive/CAB/CAB_dataset/TxtImg"

for f in os.listdir(img_source_path):
  if f.endswith(".jpg"):
    shutil.move(os.path.join(img_source_path, f), dest_path)

for f in os.listdir(txt_source_path):
  if f.endswith(".txt"):
    shutil.move(os.path.join(txt_source_path, f), dest_path)

# %% [markdown]
# 전체 이미지를 6:2:2 비율로 나누어 train set, validation set, test set을 생성한다.

# %%
data_root = "/content/drive/MyDrive/CAB/CAB_dataset/"

train_root = os.path.join(data_root, "train")
val_root = os.path.join(data_root, "val")
test_root = os.path.join(data_root, "test")

os.makedirs(train_root, exist_ok=True)
os.makedirs(val_root, exist_ok=True)
os.makedirs(test_root, exist_ok=True)

# %%
random.shuffle(img_files)

for idx, img_src in tqdm(enumerate(img_files)):
  txt_src = os.path.splitext(img_src)[0] + ".txt"
  img_name = os.path.split(img_src)[-1]
  text_name = os.path.split(txt_src)[-1]

  if idx % 10 < 6:
    img_dst = os.path.join(train_root, img_name)
    txt_dst = os.path.join(train_root, text_name)
  elif idx % 10 < 8:
    img_dst = os.path.join(val_root, img_name)
    txt_dst = os.path.join(val_root, text_name)
  else:
    img_dst = os.path.join(test_root, img_name)
    txt_dst = os.path.join(test_root, text_name)

  shutil.copy2(img_src, img_dst)
  shutil.copy2(txt_src, txt_dst)
# Out:
# 12563it [09:05, 23.02it/s]

# %% [markdown]
# 추후 훈련된 모델을 이용하여 예측할 이미지 폴더를 생성한다.

# %%
test_no_txt = os.path.join(data_root, "test_no_txt")
os.makedirs(test_no_txt, exist_ok=True)

for f in os.listdir(test_root):
  if f.endswith(".jpg"):
    src_path = os.path.join(test_root, f)
    dst_path = os.path.join(test_no_txt, f)

    shutil.copy2(src_path, dst_path)

# %% [markdown]
# train, val, test, test_no_txt 폴더에 이미지들이 잘 옮겨졌는지 확인한다.

# %%
def count_img_files(directory):
  f = [f for f in os.listdir(directory) if f.endswith(".jpg")]
  return len(f)

count_img_files(train_root)
count_img_files(val_root)
count_img_files(test_root)
# count_img_files(test_no_txt)

# %% [markdown]
# **YOLOv5 환경 구성**

# %%
# !git clone -b v7.0 https://github.com/jetsonai/yolov5
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15656, done.
# remote: Total 15656 (delta 0), reused 0 (delta 0), pack-reused 15656 (from 1)
# Receiving objects: 100% (15656/15656), 14.50 MiB | 18.42 MiB/s, done.
# Resolving deltas: 100% (10695/10695), done.
# Note: switching to '915bbf294bb74c859f0b41f1c23bc395014ea679'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# /content/yolov5

# %% [markdown]
# **Train**

# %% [markdown]
# 훈련을 위한 설정 파일, yaml 파일을 제작한다.

# %%
text_lines = '''
train:
  - /content/drive/MyDrive/CAB/CAB_dataset/train
val:
  - /content/drive/MyDrive/CAB/CAB_dataset/val
test:
  - /content/drive/MyDrive/CAB/CAB_dataset/test

# Classes
names:
  0: Face
  1: Leye
  2: Reye
  3: Mouth
  4: Cigar
  5: Phone
'''

with open("/content/yolov5/cabdata.yaml", 'w') as f:
    f.write(text_lines)

# %%
# !python train.py --img 480 --batch 32 --epochs 20 --data cabdata.yaml --weights yolov5s.pt --cache
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#        9/19      4.22G    0.02884    0.01762   0.003289        250        480:  70% 166/236 [01:06<00:21,  3.20it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01763   0.003297        231        480:  71% 167/236 [01:06<00:21,  3.22it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01762   0.003296        195        480:  71% 168/236 [01:06<00:21,  3.22it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01762   0.003294        224        480:  72% 169/236 [01:07<00:20,  3.28it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02885    0.01761   0.003297        191        480:  72% 170/236 [01:07<00:19,  3.30it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01758   0.003295        163        480:  72% 171/236 [01:07<00:19,  3.40it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01757   0.003293        208        480:  73% 172/236 [01:08<00:20,  3.18it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01758   0.003296        233        480:  73% 173/236 [01:08<00:19,  3.27it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01758   0.003291        229        480:  74% 174/236 [01:08<00:20,  2.97it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02889    0.01758    0.00329        236        480:  74% 175/236 [01:09<00:20,  3.00it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01758   0.003288        213        480:  75% 176/236 [01:09<00:26,  2.27it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01757   0.003287        206        480:  75% 177/236 [01:09<00:22,  2.57it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01756   0.003284        238        480:  75% 178/236 [01:10<00:25,  2.24it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02889    0.01757   0.003283        210        480:  76% 179/236 [01:10<00:24,  2.33it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02891    0.01757   0.003285        212        480:  76% 180/236 [01:11<00:25,  2.23it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02891    0.01756   0.003284        205        480:  77% 181/236 [01:11<00:24,  2.21it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02891    0.01755   0.003287        193        480:  77% 182/236 [01:12<00:25,  2.13it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G     0.0289    0.01753   0.003286        202        480:  78% 183/236 [01:12<00:23,  2.22it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02889    0.01753   0.003283        225        480:  78% 184/236 [01:13<00:25,  2.07it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02889    0.01754   0.003286        233        480:  78% 185/236 [01:13<00:24,  2.12it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02889    0.01754   0.003284        219        480:  79% 186/236 [01:14<00:24,  2.03it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02888    0.01754   0.003282        235        480:  79% 187/236 [01:14<00:23,  2.11it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01756   0.003285        319        480:  80% 188/236 [01:15<00:24,  1.96it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02886    0.01754   0.003286        155        480:  80% 189/236 [01:15<00:23,  2.01it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02887    0.01753   0.003284        207        480:  81% 190/236 [01:16<00:24,  1.85it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.02887    0.01753   0.003282        210        480:  81% 191/236 [01:16<00:21,  2.09it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/19      4.22G    0.
/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02253    0.01555   0.002349        224        480:  97% 230/236 [01:32<00:03,  1.85it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01555   0.002349        235        480:  98% 231/236 [01:32<00:02,  2.06it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01556   0.002346        239        480:  98% 232/236 [01:33<00:02,  1.86it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01556   0.002344        222        480:  99% 233/236 [01:33<00:01,  2.11it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01556   0.002344        245        480:  99% 234/236 [01:34<00:01,  1.88it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01556   0.002355        204        480: 100% 235/236 [01:34<00:00,  2.15it/s]/content/yolov5/train.py:307: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/19      4.22G    0.02252    0.01556   0.002355        129        480: 100% 236/236 [01:35<00:00,  2.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 40/40 [00:25<00:00,  1.57it/s]
#                    all       2512       9547      0.982       0.98      0.986      0.664
#
# 20 epochs completed in 0.652 hours.
# /content/yolov5/utils/general.py:1004: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   x = torch.load(f, map_location=torch.device('cpu'))
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.3MB
#
# Validating runs/train/exp4/weights/best.pt...
# /content/yolov5/models/experimental.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   2% 1/40 [00:00<00:24,  1.57it/s]Exception in thread Thread-23 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-24 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   5% 2/40 [00:01<00:36,  1.03it/s]Exception in thread Thread-25 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-26 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   8% 3/40 [00:02<00:34,  1.07it/s]Exception in thread Thread-27 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-28 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 40/40 [00:28<00:00,  1.40it/s]
#                    all       2512       9547      0.982       0.98      0.986      0.664
#                   Face       2512       2512      0.999          1      0.995      0.914
#                   Leye       2512       2449       0.99       0.99      0.993      0.631
#                   Reye       2512       2306      0.984      0.974      0.991      0.613
#                  Mouth       2512       1747      0.988      0.995      0.995      0.688
#                  Cigar       2512        254       0.94      0.937      0.956      0.449
#                  Phone       2512        279      0.992      0.982      0.988      0.689
# Results saved to runs/train/exp4

# %%
files.download('/content/yolov5/runs/train/exp4/weights/best.pt')

# %% [markdown]
# **TEST**

# %%
# !python val.py --task "test" --img 480 --batch 32 --data cabdata.yaml --weights /content/yolov5/runs/train/exp4/weights/best.pt
# Out:
# val: data=cabdata.yaml, weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=480, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-0-g915bbf29 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# /content/yolov5/models/experimental.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/CAB/CAB_dataset/test... 2512 images, 0 backgrounds, 0 corrupt: 100% 2512/2512 [02:21<00:00, 17.72it/s]
# test: New cache created: /content/drive/MyDrive/CAB/CAB_dataset/test.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   1% 1/79 [00:02<03:26,  2.65s/it]Exception in thread Thread-6 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-7 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   3% 2/79 [00:03<01:50,  1.43s/it]Exception in thread Thread-8 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-9 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   4% 3/79 [00:03<01:21,  1.08s/it]Exception in thread Thread-10 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-11 (plot_images):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/yolov5/utils/plots.py", line 305, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/content/yolov5/utils/plots.py", line 91, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 79/79 [00:49<00:00,  1.59it/s]
#                    all       2512       9536      0.979      0.978      0.986      0.668
#                   Face       2512       2512          1          1      0.995       0.91
#                   Leye       2512       2445      0.987      0.991      0.993      0.629
#                   Reye       2512       2293      0.983       0.97      0.991      0.617
#                  Mouth       2512       1756      0.986      0.995      0.994      0.691
#                  Cigar       2512        244       0.94      0.939       0.96      0.471
#                  Phone       2512        286      0.979      0.971      0.983      0.689
# Speed: 0.1ms pre-process, 2.5ms inference, 2.8ms NMS per image at shape (32, 3, 480, 480)
# Results saved to runs/val/exp
